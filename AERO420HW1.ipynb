# %% [markdown]
# <a href="https://colab.research.google.com/github/jfink09/Aerospace-Engineering/blob/master/AERO420HW1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#AERO 420 HW #1 Code Jason Fink

# Import Libraries
import pandas as pd 
import numpy as np
import io
import matplotlib.pyplot as plt

from matplotlib.pyplot import style
from matplotlib.pyplot import figure

# %%
# Create file upload button to take the array created from Matlab in as an xlsx file
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-50ae1a4c-76dc-49b3-8e38-eb8a788335a4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-50ae1a4c-76dc-49b3-8e38-eb8a788335a4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving aero_420_hw1.xlsx to aero_420_hw1.xlsx

# %%
# Create a Pandas Dataframe to extract the array from the csv file
df = pd.read_excel(io.BytesIO(upload['aero_420_hw1.xlsx']))
df
# Out:
#          2         3         4    ...       99        100       101
# 0   0.002567  0.002562  0.002556  ...  0.002122  0.002118  0.002114
# 1   0.002558  0.002553  0.002547  ...  0.002114  0.002110  0.002107
# 2   0.002549  0.002543  0.002538  ...  0.002107  0.002103  0.002099
# 3   0.002540  0.002534  0.002529  ...  0.002099  0.002095  0.002091
# 4   0.002530  0.002525  0.002519  ...  0.002091  0.002088  0.002084
# 5   0.002521  0.002516  0.002510  ...  0.002084  0.002080  0.002076
# 6   0.002512  0.002506  0.002501  ...  0.002076  0.002072  0.002069
# 7   0.002503  0.002497  0.002492  ...  0.002068  0.002065  0.002061
# 8   0.002494  0.002488  0.002483  ...  0.002061  0.002057  0.002054
# 9   0.002484  0.002479  0.002474  ...  0.002053  0.002050  0.002046
# 10  0.002475  0.002470  0.002465  ...  0.002046  0.002042  0.002039
# 11  0.002466  0.002461  0.002456  ...  0.002038  0.002035  0.002031
#
# [12 rows x 100 columns]

# %%
# Rename columns with the corresponding pressure altitudes
df.index = ['PA_1000', 'PA_1100', 'PA_1200', 'PA_1300', 'PA_1400', 'PA_1500', 'PA_1600', 'PA_1700', 'PA_1800', 'PA_1900', 'PA_2000', 'PA_2100']

# Transpose the array so that temperature changes with each row and pressure altitude changes with each column
df_transpose = df.T
df_transpose
# Out:
#       PA_1000   PA_1100   PA_1200  ...   PA_1900   PA_2000   PA_2100
# 2    0.002567  0.002558  0.002549  ...  0.002484  0.002475  0.002466
# 3    0.002562  0.002553  0.002543  ...  0.002479  0.002470  0.002461
# 4    0.002556  0.002547  0.002538  ...  0.002474  0.002465  0.002456
# 5    0.002551  0.002542  0.002532  ...  0.002468  0.002459  0.002450
# 6    0.002545  0.002536  0.002527  ...  0.002463  0.002454  0.002445
# ..        ...       ...       ...  ...       ...       ...       ...
# 97   0.002130  0.002122  0.002114  ...  0.002061  0.002053  0.002046
# 98   0.002126  0.002118  0.002110  ...  0.002057  0.002050  0.002042
# 99   0.002122  0.002114  0.002107  ...  0.002053  0.002046  0.002038
# 100  0.002118  0.002110  0.002103  ...  0.002050  0.002042  0.002035
# 101  0.002114  0.002107  0.002099  ...  0.002046  0.002039  0.002031
#
# [100 rows x 12 columns]

# %%
# Store each column as its own variable to be plotted
df_transpose_1 = df_transpose['PA_1000']
df_transpose_2 = df_transpose['PA_1100']
df_transpose_3 = df_transpose['PA_1200']
df_transpose_4 = df_transpose['PA_1300']
df_transpose_5 = df_transpose['PA_1400']
df_transpose_6 = df_transpose['PA_1500']
df_transpose_7 = df_transpose['PA_1600']
df_transpose_8 = df_transpose['PA_1700']
df_transpose_9 = df_transpose['PA_1800']
df_transpose_10 = df_transpose['PA_1900']
df_transpose_11 = df_transpose['PA_2000']
df_transpose_12 = df_transpose['PA_2100']

# %%
# Set up the plot style and size
plt.style.use('fivethirtyeight')                   
plt.figure(figsize=(15,10))

# Plot the dataframe using the variables stored
plt.plot(df_1, label="Density at PA_1000 (ft)")  
plt.plot(df_2, label="Density at PA_1100 (ft)")   
plt.plot(df_3, label="Density at PA_1200 (ft)")   
plt.plot(df_4, label="Density at PA_1300 (ft)")   
plt.plot(df_5, label="Density at PA_1400 (ft)")  
plt.plot(df_6, label="Density at PA_1500 (ft)")    
plt.plot(df_7, label="Density at PA_1600 (ft)") 
plt.plot(df_8, label="Density at PA_1700 (ft)") 
plt.plot(df_9, label="Density at PA_1800 (ft)") 
plt.plot(df_10, label="Density at PA_1900 (ft)") 
plt.plot(df_11, label="Density at PA_2000 (ft)") 
plt.plot(df_12, label="Density at PA_2100 (ft)") 

# Label the axes and give the plot a title and legend
plt.title('Denisty Versus Temperature at Constant Pressure Altitude')                                     
plt.xlabel('Temperature (Deg F)', fontsize=12)                          
plt.ylabel('Density (slugs/ft^3)', fontsize=12)       
plt.legend(prop={"size":10})                                     
plt.tight_layout                                                  # Tight layout format
# Out:
# <function matplotlib.pyplot.tight_layout>

# %%
# Add another plot to show how to use it
fig, ax = plt.subplots(figsize=(15, 10))
ax.plot(df_transpose_12, label="Density at PA_2100 (ft)") 

# Add horizontal and vertical lines to show how to read the plot
ax.hlines(y=0.0021912, xmin=0, xmax=60, linewidth=2, color='r', linestyles='--')
ax.vlines(x=60, ymin=0, ymax=0.0021912, linewidth=2, colors='r', linestyles='--')

# Show the coordinate 
ax.annotate('(60, 0.0021912)', xy=(60, 0.0022),  xycoords='data',
            xytext=(0.8, 0.95), textcoords='axes fraction',
            arrowprops=dict(facecolor='black', shrink=0.05),
            horizontalalignment='right', verticalalignment='top',
            )

plt.tight_layout()
